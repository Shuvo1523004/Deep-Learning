# %% [markdown]
# <a href="https://colab.research.google.com/github/Shuvo1523004/Deep-Learning/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-acdmpvi3
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-acdmpvi3
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=e3fe7af4b42c90c8016694b8fe3e1fc88f53a4b38825aac92cc7d96f1d2a4a1a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mflabm59/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.296588, train error 90.18,  test loss 2.296543, test error 90.55
# Epoch   100, train loss 1.897564, train error 72.38,  test loss 1.748330, test error 69.53
# Epoch   200, train loss 1.888372, train error 70.97,  test loss 1.730864, test error 68.97
# Epoch   300, train loss 1.887222, train error 71.75,  test loss 1.727371, test error 69.95
# Epoch   400, train loss 1.885873, train error 71.20,  test loss 1.726973, test error 69.25
# Epoch   500, train loss 1.885646, train error 70.85,  test loss 1.719324, test error 68.97
# Epoch   600, train loss 1.883927, train error 70.60,  test loss 1.719017, test error 69.65
# Epoch   700, train loss 1.884429, train error 70.57,  test loss 1.719947, test error 69.15
# Epoch   800, train loss 1.885054, train error 71.70,  test loss 1.721333, test error 68.90
# Epoch   900, train loss 1.886400, train error 71.03,  test loss 1.728421, test error 68.90
# Training model with   4 hidden variables
# Epoch     0, train loss 2.294969, train error 86.45,  test loss 2.288144, test error 85.22
# Epoch   100, train loss 1.785671, train error 66.43,  test loss 1.619029, test error 63.62
# Epoch   200, train loss 1.769835, train error 65.35,  test loss 1.608539, test error 62.97
# Epoch   300, train loss 1.752701, train error 64.78,  test loss 1.591074, test error 62.42
# Epoch   400, train loss 1.750067, train error 65.57,  test loss 1.585624, test error 62.35
# Epoch   500, train loss 1.727821, train error 63.28,  test loss 1.535346, test error 60.00
# Epoch   600, train loss 1.708352, train error 61.72,  test loss 1.526183, test error 58.30
# Epoch   700, train loss 1.706774, train error 61.70,  test loss 1.526348, test error 58.47
# Epoch   800, train loss 1.707114, train error 61.70,  test loss 1.538136, test error 58.72
# Epoch   900, train loss 1.705284, train error 61.53,  test loss 1.535405, test error 57.97
# Training model with   6 hidden variables
# Epoch     0, train loss 2.284121, train error 86.03,  test loss 2.283918, test error 85.12
# Epoch   100, train loss 1.648783, train error 58.70,  test loss 1.465458, test error 56.80
# Epoch   200, train loss 1.615018, train error 57.78,  test loss 1.439319, test error 55.62
# Epoch   300, train loss 1.616162, train error 58.30,  test loss 1.444626, test error 55.55
# Epoch   400, train loss 1.606335, train error 57.47,  test loss 1.435333, test error 55.35
# Epoch   500, train loss 1.600958, train error 57.35,  test loss 1.442683, test error 55.05
# Epoch   600, train loss 1.606665, train error 57.47,  test loss 1.453883, test error 54.65
# Epoch   700, train loss 1.596596, train error 57.50,  test loss 1.446324, test error 54.95
# Epoch   800, train loss 1.604292, train error 57.92,  test loss 1.456898, test error 55.10
# Epoch   900, train loss 1.590192, train error 56.70,  test loss 1.439154, test error 54.33
# Training model with   8 hidden variables
# Epoch     0, train loss 2.295028, train error 87.47,  test loss 2.293876, test error 86.53
# Epoch   100, train loss 1.652149, train error 58.67,  test loss 1.493290, test error 56.25
# Epoch   200, train loss 1.605243, train error 56.90,  test loss 1.485282, test error 56.40
# Epoch   300, train loss 1.586016, train error 56.10,  test loss 1.488708, test error 56.20
# Epoch   400, train loss 1.572371, train error 56.10,  test loss 1.489983, test error 55.97
# Epoch   500, train loss 1.567045, train error 55.80,  test loss 1.493932, test error 56.03
# Epoch   600, train loss 1.554239, train error 55.25,  test loss 1.495165, test error 55.55
# Epoch   700, train loss 1.550734, train error 55.38,  test loss 1.499526, test error 55.88
# Epoch   800, train loss 1.545569, train error 55.80,  test loss 1.498330, test error 55.38
# Epoch   900, train loss 1.544753, train error 54.92,  test loss 1.490707, test error 55.53
# Training model with  10 hidden variables
# Epoch     0, train loss 2.277099, train error 84.95,  test loss 2.274180, test error 85.40
# Epoch   100, train loss 1.462961, train error 49.12,  test loss 1.291076, test error 47.75
# Epoch   200, train loss 1.421327, train error 48.85,  test loss 1.293521, test error 48.20
# Epoch   300, train loss 1.401119, train error 48.25,  test loss 1.304191, test error 49.05
# Epoch   400, train loss 1.390072, train error 47.95,  test loss 1.315174, test error 49.20
# Epoch   500, train loss 1.382783, train error 48.22,  test loss 1.304180, test error 48.78
# Epoch   600, train loss 1.380769, train error 47.70,  test loss 1.306473, test error 48.58
# Epoch   700, train loss 1.375697, train error 47.33,  test loss 1.301350, test error 48.65
# Epoch   800, train loss 1.379844, train error 46.97,  test loss 1.310983, test error 48.88
# Epoch   900, train loss 1.372421, train error 47.38,  test loss 1.313858, test error 48.58
# Training model with  14 hidden variables
# Epoch     0, train loss 2.282560, train error 83.90,  test loss 2.277062, test error 83.07
# Epoch   100, train loss 1.399463, train error 46.75,  test loss 1.275338, test error 47.70
# Epoch   200, train loss 1.334942, train error 45.35,  test loss 1.281237, test error 47.95
# Epoch   300, train loss 1.297937, train error 43.72,  test loss 1.281582, test error 47.28
# Epoch   400, train loss 1.278162, train error 43.65,  test loss 1.300575, test error 47.50
# Epoch   500, train loss 1.255609, train error 43.28,  test loss 1.308921, test error 47.30
# Epoch   600, train loss 1.248829, train error 42.60,  test loss 1.323734, test error 47.53
# Epoch   700, train loss 1.240026, train error 42.67,  test loss 1.336267, test error 48.10
# Epoch   800, train loss 1.225324, train error 41.85,  test loss 1.347361, test error 47.50
# Epoch   900, train loss 1.228385, train error 42.45,  test loss 1.366938, test error 48.10
# Training model with  18 hidden variables
# Epoch     0, train loss 2.192229, train error 81.72,  test loss 2.162739, test error 80.65
# Epoch   100, train loss 1.325975, train error 43.92,  test loss 1.279254, test error 47.65
# Epoch   200, train loss 1.234785, train error 41.30,  test loss 1.307747, test error 47.45
# Epoch   300, train loss 1.196764, train error 39.83,  test loss 1.366105, test error 49.40
# Epoch   400, train loss 1.178876, train error 39.08,  test loss 1.378905, test error 49.38
# Epoch   500, train loss 1.171146, train error 39.22,  test loss 1.404046, test error 50.20
# Epoch   600, train loss 1.157627, train error 38.75,  test loss 1.432750, test error 50.70
# Epoch   700, train loss 1.157712, train error 39.50,  test loss 1.470982, test error 51.55
# Epoch   800, train loss 1.135334, train error 38.47,  test loss 1.465784, test error 51.15
# Epoch   900, train loss 1.130263, train error 37.83,  test loss 1.472642, test error 51.50
# Training model with  22 hidden variables
# Epoch     0, train loss 2.147877, train error 81.47,  test loss 2.119080, test error 79.05
# Epoch   100, train loss 1.276969, train error 42.20,  test loss 1.363598, test error 50.55
# Epoch   200, train loss 1.155348, train error 38.62,  test loss 1.410508, test error 50.17
# Epoch   300, train loss 1.094653, train error 36.55,  test loss 1.446512, test error 50.65
# Epoch   400, train loss 1.053128, train error 35.82,  test loss 1.490930, test error 50.67
# Epoch   500, train loss 1.045153, train error 35.15,  test loss 1.538404, test error 51.62
# Epoch   600, train loss 1.024645, train error 35.40,  test loss 1.586506, test error 52.38
# Epoch   700, train loss 1.003726, train error 33.72,  test loss 1.601781, test error 51.72
# Epoch   800, train loss 1.003610, train error 34.72,  test loss 1.665935, test error 52.60
# Epoch   900, train loss 0.979300, train error 33.50,  test loss 1.689120, test error 52.17
# Training model with  26 hidden variables
# Epoch     0, train loss 2.105435, train error 79.72,  test loss 2.061062, test error 78.82
# Epoch   100, train loss 1.163316, train error 39.67,  test loss 1.333245, test error 49.17
# Epoch   200, train loss 1.021497, train error 35.03,  test loss 1.436599, test error 49.92
# Epoch   300, train loss 0.964741, train error 33.05,  test loss 1.590682, test error 50.83
# Epoch   400, train loss 0.920261, train error 32.05,  test loss 1.665874, test error 51.83
# Epoch   500, train loss 0.898174, train error 31.57,  test loss 1.769158, test error 52.67
# Epoch   600, train loss 0.862289, train error 29.85,  test loss 1.841980, test error 52.47
# Epoch   700, train loss 0.851665, train error 29.78,  test loss 1.904578, test error 53.03
# Epoch   800, train loss 0.845165, train error 29.55,  test loss 1.995482, test error 54.10
# Epoch   900, train loss 0.824944, train error 28.68,  test loss 2.044381, test error 54.00
# Training model with  30 hidden variables
# Epoch     0, train loss 2.124590, train error 79.50,  test loss 2.092704, test error 79.35
# Epoch   100, train loss 1.121761, train error 37.50,  test loss 1.412029, test error 50.28
# Epoch   200, train loss 0.922067, train error 30.65,  test loss 1.610542, test error 51.47
# Epoch   300, train loss 0.832946, train error 27.88,  test loss 1.821111, test error 53.30
# Epoch   400, train loss 0.782615, train error 26.82,  test loss 1.998111, test error 54.30
# Epoch   500, train loss 0.737291, train error 25.15,  test loss 2.152526, test error 54.58
# Epoch   600, train loss 0.705616, train error 24.28,  test loss 2.291086, test error 55.22
# Epoch   700, train loss 0.683673, train error 23.28,  test loss 2.386503, test error 54.58
# Epoch   800, train loss 0.691709, train error 23.72,  test loss 2.512228, test error 55.88
# Epoch   900, train loss 0.672368, train error 22.75,  test loss 2.595959, test error 55.67
# Training model with  35 hidden variables
# Epoch     0, train loss 2.252246, train error 82.88,  test loss 2.238553, test error 82.55
# Epoch   100, train loss 1.034652, train error 33.30,  test loss 1.448700, test error 51.60
# Epoch   200, train loss 0.783703, train error 25.88,  test loss 1.810476, test error 54.35
# Epoch   300, train loss 0.679554, train error 23.03,  test loss 2.147429, test error 54.60
# Epoch   400, train loss 0.587346, train error 19.72,  test loss 2.429556, test error 54.88
# Epoch   500, train loss 0.554391, train error 19.18,  test loss 2.812539, test error 56.15
# Epoch   600, train loss 0.518616, train error 18.35,  test loss 3.092858, test error 55.50
# Epoch   700, train loss 0.473495, train error 16.40,  test loss 3.440516, test error 55.85
# Epoch   800, train loss 0.468941, train error 16.95,  test loss 3.847094, test error 56.72
# Epoch   900, train loss 0.418804, train error 14.70,  test loss 4.197268, test error 57.53
# Training model with  40 hidden variables
# Epoch     0, train loss 2.138678, train error 79.88,  test loss 2.110359, test error 78.22
# Epoch   100, train loss 0.909422, train error 30.30,  test loss 1.419510, test error 49.47
# Epoch   200, train loss 0.655396, train error 21.65,  test loss 1.894336, test error 51.62
# Epoch   300, train loss 0.490806, train error 16.55,  test loss 2.501188, test error 52.60
# Epoch   400, train loss 0.436644, train error 15.47,  test loss 3.142872, test error 53.45
# Epoch   500, train loss 0.370275, train error 12.97,  test loss 3.713623, test error 53.85
# Epoch   600, train loss 0.307079, train error 10.90,  test loss 4.390738, test error 55.08
# Epoch   700, train loss 0.268624, train error 9.25,  test loss 5.146985, test error 55.58
# Epoch   800, train loss 0.296728, train error 11.03,  test loss 5.707372, test error 55.53
# Epoch   900, train loss 0.258499, train error 9.47,  test loss 6.368440, test error 56.85
# Training model with  45 hidden variables
# Epoch     0, train loss 2.115411, train error 79.57,  test loss 2.066316, test error 79.22
# Epoch   100, train loss 0.847298, train error 26.90,  test loss 1.400764, test error 48.40
# Epoch   200, train loss 0.498913, train error 15.93,  test loss 2.123734, test error 52.33
# Epoch   300, train loss 0.323918, train error 10.00,  test loss 3.143467, test error 55.83
# Epoch   400, train loss 0.225603, train error 7.10,  test loss 4.351003, test error 56.35
# Epoch   500, train loss 0.122315, train error 3.15,  test loss 5.556239, test error 56.50
# Epoch   600, train loss 0.273605, train error 9.22,  test loss 6.582285, test error 56.17
# Epoch   700, train loss 0.108636, train error 3.35,  test loss 7.464942, test error 56.70
# Epoch   800, train loss 0.133776, train error 4.72,  test loss 8.426328, test error 56.45
# Epoch   900, train loss 0.122316, train error 4.15,  test loss 9.242322, test error 56.62
# Training model with  50 hidden variables
# Epoch     0, train loss 2.067561, train error 77.10,  test loss 2.023833, test error 76.80
# Epoch   100, train loss 0.731411, train error 23.68,  test loss 1.512031, test error 50.17
# Epoch   200, train loss 0.358799, train error 11.32,  test loss 2.480720, test error 52.10
# Epoch   300, train loss 0.139650, train error 3.10,  test loss 3.917686, test error 53.78
# Epoch   400, train loss 0.089200, train error 2.35,  test loss 5.460565, test error 54.72
# Epoch   500, train loss 0.011474, train error 0.00,  test loss 6.400656, test error 54.80
# Epoch   600, train loss 0.007526, train error 0.00,  test loss 6.966790, test error 54.78
# Epoch   700, train loss 0.005395, train error 0.00,  test loss 7.393200, test error 54.88
# Epoch   800, train loss 0.004199, train error 0.00,  test loss 7.739084, test error 55.00
# Epoch   900, train loss 0.003370, train error 0.00,  test loss 8.027141, test error 54.72
# Training model with  55 hidden variables
# Epoch     0, train loss 2.106875, train error 77.70,  test loss 2.065151, test error 77.15
# Epoch   100, train loss 0.608227, train error 18.60,  test loss 1.696227, test error 51.35
# Epoch   200, train loss 0.191746, train error 4.45,  test loss 3.210579, test error 54.72
# Epoch   300, train loss 0.033854, train error 0.00,  test loss 5.050619, test error 55.80
# Epoch   400, train loss 0.013329, train error 0.00,  test loss 6.103871, test error 55.62
# Epoch   500, train loss 0.007894, train error 0.00,  test loss 6.756411, test error 56.08
# Epoch   600, train loss 0.005510, train error 0.00,  test loss 7.222250, test error 56.15
# Epoch   700, train loss 0.004163, train error 0.00,  test loss 7.584964, test error 56.20
# Epoch   800, train loss 0.003282, train error 0.00,  test loss 7.883143, test error 55.95
# Epoch   900, train loss 0.002714, train error 0.00,  test loss 8.137773, test error 56.03
# Training model with  60 hidden variables
# Epoch     0, train loss 2.047328, train error 75.68,  test loss 1.979277, test error 75.05
# Epoch   100, train loss 0.538312, train error 15.15,  test loss 1.727018, test error 50.10
# Epoch   200, train loss 0.109752, train error 1.05,  test loss 3.266005, test error 52.05
# Epoch   300, train loss 0.020245, train error 0.00,  test loss 4.578799, test error 52.70
# Epoch   400, train loss 0.009762, train error 0.00,  test loss 5.242485, test error 52.92
# Epoch   500, train loss 0.006158, train error 0.00,  test loss 5.681839, test error 52.90
# Epoch   600, train loss 0.004336, train error 0.00,  test loss 6.000393, test error 52.95
# Epoch   700, train loss 0.003334, train error 0.00,  test loss 6.262988, test error 52.85
# Epoch   800, train loss 0.002676, train error 0.00,  test loss 6.477046, test error 52.80
# Epoch   900, train loss 0.002222, train error 0.00,  test loss 6.654773, test error 52.78
# Training model with  70 hidden variables
# Epoch     0, train loss 2.042883, train error 76.47,  test loss 1.962230, test error 74.97
# Epoch   100, train loss 0.354048, train error 8.62,  test loss 1.930840, test error 51.58
# Epoch   200, train loss 0.031537, train error 0.00,  test loss 3.475528, test error 52.70
# Epoch   300, train loss 0.010665, train error 0.00,  test loss 4.227628, test error 52.70
# Epoch   400, train loss 0.005989, train error 0.00,  test loss 4.652792, test error 53.03
# Epoch   500, train loss 0.004008, train error 0.00,  test loss 4.943689, test error 53.10
# Epoch   600, train loss 0.002972, train error 0.00,  test loss 5.170488, test error 53.08
# Epoch   700, train loss 0.002335, train error 0.00,  test loss 5.351481, test error 53.17
# Epoch   800, train loss 0.001905, train error 0.00,  test loss 5.504335, test error 53.33
# Epoch   900, train loss 0.001604, train error 0.00,  test loss 5.636144, test error 53.45
# Training model with  80 hidden variables
# Epoch     0, train loss 2.024052, train error 75.88,  test loss 1.984527, test error 75.95
# Epoch   100, train loss 0.202827, train error 2.95,  test loss 2.134928, test error 50.58
# Epoch   200, train loss 0.018639, train error 0.00,  test loss 3.432029, test error 51.62
# Epoch   300, train loss 0.007729, train error 0.00,  test loss 3.964930, test error 51.75
# Epoch   400, train loss 0.004558, train error 0.00,  test loss 4.294572, test error 51.92
# Epoch   500, train loss 0.003166, train error 0.00,  test loss 4.524244, test error 52.08
# Epoch   600, train loss 0.002389, train error 0.00,  test loss 4.703435, test error 52.20
# Epoch   700, train loss 0.001899, train error 0.00,  test loss 4.847989, test error 52.28
# Epoch   800, train loss 0.001564, train error 0.00,  test loss 4.969851, test error 52.30
# Epoch   900, train loss 0.001324, train error 0.00,  test loss 5.074413, test error 52.47
# Training model with  90 hidden variables
# Epoch     0, train loss 1.987225, train error 74.45,  test loss 1.931793, test error 74.35
# Epoch   100, train loss 0.130685, train error 0.78,  test loss 2.115989, test error 50.70
# Epoch   200, train loss 0.014478, train error 0.00,  test loss 3.099445, test error 51.25
# Epoch   300, train loss 0.006481, train error 0.00,  test loss 3.510540, test error 51.38
# Epoch   400, train loss 0.003968, train error 0.00,  test loss 3.765482, test error 51.42
# Epoch   500, train loss 0.002790, train error 0.00,  test loss 3.950175, test error 51.30
# Epoch   600, train loss 0.002123, train error 0.00,  test loss 4.094772, test error 51.25
# Epoch   700, train loss 0.001697, train error 0.00,  test loss 4.213046, test error 51.15
# Epoch   800, train loss 0.001406, train error 0.00,  test loss 4.313997, test error 51.08
# Epoch   900, train loss 0.001193, train error 0.00,  test loss 4.399497, test error 51.15
# Training model with 100 hidden variables
# Epoch     0, train loss 1.999521, train error 75.45,  test loss 1.912411, test error 73.88
# Epoch   100, train loss 0.095561, train error 0.10,  test loss 2.207336, test error 50.65
# Epoch   200, train loss 0.012760, train error 0.00,  test loss 3.092583, test error 51.30
# Epoch   300, train loss 0.005966, train error 0.00,  test loss 3.472077, test error 51.70
# Epoch   400, train loss 0.003648, train error 0.00,  test loss 3.700066, test error 51.65
# Epoch   500, train loss 0.002583, train error 0.00,  test loss 3.866501, test error 51.55
# Epoch   600, train loss 0.001977, train error 0.00,  test loss 4.000060, test error 51.67
# Epoch   700, train loss 0.001585, train error 0.00,  test loss 4.105393, test error 51.78
# Epoch   800, train loss 0.001315, train error 0.00,  test loss 4.198204, test error 51.90
# Epoch   900, train loss 0.001119, train error 0.00,  test loss 4.277222, test error 51.88
# Training model with 120 hidden variables
# Epoch     0, train loss 1.966915, train error 72.88,  test loss 1.876270, test error 73.35
# Epoch   100, train loss 0.055152, train error 0.03,  test loss 2.172227, test error 48.88
# Epoch   200, train loss 0.009621, train error 0.00,  test loss 2.771691, test error 49.53
# Epoch   300, train loss 0.004741, train error 0.00,  test loss 3.049085, test error 49.58
# Epoch   400, train loss 0.003029, train error 0.00,  test loss 3.222975, test error 49.53
# Epoch   500, train loss 0.002182, train error 0.00,  test loss 3.354547, test error 49.53
# Epoch   600, train loss 0.001684, train error 0.00,  test loss 3.456541, test error 49.40
# Epoch   700, train loss 0.001361, train error 0.00,  test loss 3.539953, test error 49.50
# Epoch   800, train loss 0.001135, train error 0.00,  test loss 3.611183, test error 49.42
# Epoch   900, train loss 0.000969, train error 0.00,  test loss 3.673256, test error 49.45
# Training model with 140 hidden variables
# Epoch     0, train loss 1.959368, train error 73.38,  test loss 1.885701, test error 73.72
# Epoch   100, train loss 0.037489, train error 0.00,  test loss 2.116474, test error 48.85
# Epoch   200, train loss 0.008201, train error 0.00,  test loss 2.593227, test error 48.70
# Epoch   300, train loss 0.004187, train error 0.00,  test loss 2.812709, test error 49.00
# Epoch   400, train loss 0.002715, train error 0.00,  test loss 2.960781, test error 48.92
# Epoch   500, train loss 0.001969, train error 0.00,  test loss 3.070840, test error 48.90
# Epoch   600, train loss 0.001529, train error 0.00,  test loss 3.157541, test error 48.88
# Epoch   700, train loss 0.001241, train error 0.00,  test loss 3.229560, test error 48.80
# Epoch   800, train loss 0.001038, train error 0.00,  test loss 3.291319, test error 48.85
# Epoch   900, train loss 0.000889, train error 0.00,  test loss 3.344989, test error 48.83
# Training model with 160 hidden variables
# Epoch     0, train loss 1.936136, train error 71.88,  test loss 1.890982, test error 72.20
# Epoch   100, train loss 0.028129, train error 0.00,  test loss 2.067933, test error 49.35
# Epoch   200, train loss 0.007160, train error 0.00,  test loss 2.464625, test error 49.30
# Epoch   300, train loss 0.003771, train error 0.00,  test loss 2.658770, test error 49.42
# Epoch   400, train loss 0.002482, train error 0.00,  test loss 2.787728, test error 49.47
# Epoch   500, train loss 0.001818, train error 0.00,  test loss 2.885282, test error 49.50
# Epoch   600, train loss 0.001420, train error 0.00,  test loss 2.962556, test error 49.40
# Epoch   700, train loss 0.001156, train error 0.00,  test loss 3.026278, test error 49.45
# Epoch   800, train loss 0.000970, train error 0.00,  test loss 3.081773, test error 49.47
# Epoch   900, train loss 0.000833, train error 0.00,  test loss 3.130073, test error 49.45
# Training model with 180 hidden variables
# Epoch     0, train loss 1.914640, train error 70.68,  test loss 1.837203, test error 72.25
# Epoch   100, train loss 0.024274, train error 0.00,  test loss 2.057977, test error 48.12
# Epoch   200, train loss 0.006529, train error 0.00,  test loss 2.405226, test error 48.05
# Epoch   300, train loss 0.003493, train error 0.00,  test loss 2.580018, test error 48.20
# Epoch   400, train loss 0.002313, train error 0.00,  test loss 2.699163, test error 48.12
# Epoch   500, train loss 0.001702, train error 0.00,  test loss 2.786324, test error 48.15
# Epoch   600, train loss 0.001333, train error 0.00,  test loss 2.857166, test error 48.08
# Epoch   700, train loss 0.001089, train error 0.00,  test loss 2.915691, test error 48.03
# Epoch   800, train loss 0.000916, train error 0.00,  test loss 2.965786, test error 47.97
# Epoch   900, train loss 0.000787, train error 0.00,  test loss 3.010471, test error 47.97
# Training model with 200 hidden variables
# Epoch     0, train loss 1.914854, train error 69.18,  test loss 1.843057, test error 70.82
# Epoch   100, train loss 0.021847, train error 0.00,  test loss 2.027006, test error 48.33
# Epoch   200, train loss 0.006181, train error 0.00,  test loss 2.345834, test error 48.12
# Epoch   300, train loss 0.003349, train error 0.00,  test loss 2.510090, test error 47.97
# Epoch   400, train loss 0.002233, train error 0.00,  test loss 2.621264, test error 48.08
# Epoch   500, train loss 0.001649, train error 0.00,  test loss 2.704364, test error 47.97
# Epoch   600, train loss 0.001295, train error 0.00,  test loss 2.772058, test error 48.10
# Epoch   700, train loss 0.001059, train error 0.00,  test loss 2.827296, test error 48.20
# Epoch   800, train loss 0.000892, train error 0.00,  test loss 2.875697, test error 48.12
# Epoch   900, train loss 0.000767, train error 0.00,  test loss 2.917157, test error 48.20
# Training model with 250 hidden variables
# Epoch     0, train loss 1.920984, train error 70.57,  test loss 1.834205, test error 70.88
# Epoch   100, train loss 0.017319, train error 0.00,  test loss 1.846123, test error 46.60
# Epoch   200, train loss 0.005373, train error 0.00,  test loss 2.088723, test error 46.47
# Epoch   300, train loss 0.002987, train error 0.00,  test loss 2.218174, test error 46.00
# Epoch   400, train loss 0.002014, train error 0.00,  test loss 2.305519, test error 46.05
# Epoch   500, train loss 0.001498, train error 0.00,  test loss 2.372090, test error 45.90
# Epoch   600, train loss 0.001183, train error 0.00,  test loss 2.425764, test error 45.95
# Epoch   700, train loss 0.000970, train error 0.00,  test loss 2.471019, test error 45.97
# Epoch   800, train loss 0.000819, train error 0.00,  test loss 2.509684, test error 45.90
# Epoch   900, train loss 0.000707, train error 0.00,  test loss 2.544174, test error 45.92
# Training model with 300 hidden variables
# Epoch     0, train loss 1.873999, train error 68.10,  test loss 1.780265, test error 69.35
# Epoch   100, train loss 0.014531, train error 0.00,  test loss 1.841248, test error 46.05
# Epoch   200, train loss 0.004849, train error 0.00,  test loss 2.055882, test error 45.97
# Epoch   300, train loss 0.002739, train error 0.00,  test loss 2.171135, test error 45.90
# Epoch   400, train loss 0.001863, train error 0.00,  test loss 2.250702, test error 45.83
# Epoch   500, train loss 0.001393, train error 0.00,  test loss 2.311317, test error 45.78
# Epoch   600, train loss 0.001103, train error 0.00,  test loss 2.360304, test error 45.97
# Epoch   700, train loss 0.000908, train error 0.00,  test loss 2.401550, test error 45.90
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.437021, test error 45.80
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.468091, test error 45.85
# Training model with 400 hidden variables
# Epoch     0, train loss 1.835613, train error 66.18,  test loss 1.784724, test error 69.47
# Epoch   100, train loss 0.011729, train error 0.00,  test loss 1.806075, test error 45.90
# Epoch   200, train loss 0.004166, train error 0.00,  test loss 1.992007, test error 45.97
# Epoch   300, train loss 0.002413, train error 0.00,  test loss 2.093963, test error 45.88
# Epoch   400, train loss 0.001661, train error 0.00,  test loss 2.164721, test error 45.78
# Epoch   500, train loss 0.001251, train error 0.00,  test loss 2.219721, test error 45.65
# Epoch   600, train loss 0.000996, train error 0.00,  test loss 2.263778, test error 45.70
# Epoch   700, train loss 0.000823, train error 0.00,  test loss 2.301224, test error 45.72
# Epoch   800, train loss 0.000699, train error 0.00,  test loss 2.333822, test error 45.67
# Epoch   900, train loss 0.000606, train error 0.00,  test loss 2.362064, test error 45.62

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
