# %% [markdown]
# <a href="https://colab.research.google.com/github/Shuvo1523004/Deep-Learning/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-1twnfhtb
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-1twnfhtb
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=1993bbcb7af58ad4c0aca934d589582b36a678505828700acd6438da2de4826e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2lqvme4f/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Structure: Linear -> ReLU -> Linear -> ReLU -> Linear

model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),   # Input -> Hidden layer 1
    torch.nn.ReLU(),              # ReLU activation
    torch.nn.Linear(D_k, D_k),   # Hidden layer 1 -> Hidden layer 2
    torch.nn.ReLU(),              # ReLU activation
    torch.nn.Linear(D_k, D_o)    # Hidden layer 2 -> Output
)

def weights_init(layer_in):
    # Initialize the parameters with He initialization
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight, nonlinearity='relu')
        nn.init.zeros_(layer_in.bias)

# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.606774, train error 63.28,  test loss 1.707995, test error 69.50
# Epoch     1, train loss 1.304679, train error 46.17,  test loss 1.477593, test error 58.60
# Epoch     2, train loss 1.123720, train error 41.17,  test loss 1.339056, test error 51.20
# Epoch     3, train loss 1.002670, train error 37.92,  test loss 1.294150, test error 50.30
# Epoch     4, train loss 0.877466, train error 30.93,  test loss 1.224760, test error 46.70
# Epoch     5, train loss 0.773953, train error 27.20,  test loss 1.154485, test error 44.60
# Epoch     6, train loss 0.680934, train error 23.30,  test loss 1.121485, test error 43.60
# Epoch     7, train loss 0.635748, train error 22.03,  test loss 1.094977, test error 40.70
# Epoch     8, train loss 0.589594, train error 20.65,  test loss 1.142571, test error 41.10
# Epoch     9, train loss 0.492405, train error 15.80,  test loss 1.112699, test error 40.90
# Epoch    10, train loss 0.396390, train error 11.43,  test loss 1.059857, test error 38.50
# Epoch    11, train loss 0.362415, train error 9.97,  test loss 1.091895, test error 39.20
# Epoch    12, train loss 0.327546, train error 8.88,  test loss 1.088323, test error 38.30
# Epoch    13, train loss 0.293396, train error 7.15,  test loss 1.086312, test error 37.40
# Epoch    14, train loss 0.274016, train error 6.50,  test loss 1.106726, test error 37.60
# Epoch    15, train loss 0.247849, train error 5.15,  test loss 1.126024, test error 38.00
# Epoch    16, train loss 0.232160, train error 5.30,  test loss 1.145867, test error 38.70
# Epoch    17, train loss 0.212935, train error 4.50,  test loss 1.140881, test error 37.10
# Epoch    18, train loss 0.196096, train error 3.78,  test loss 1.169038, test error 37.20
# Epoch    19, train loss 0.172493, train error 2.62,  test loss 1.156690, test error 37.30
# Epoch    20, train loss 0.146012, train error 1.72,  test loss 1.202601, test error 36.80
# Epoch    21, train loss 0.139998, train error 1.40,  test loss 1.217127, test error 37.90
# Epoch    22, train loss 0.133412, train error 1.20,  test loss 1.227286, test error 37.50
# Epoch    23, train loss 0.125035, train error 0.85,  test loss 1.231730, test error 37.70
# Epoch    24, train loss 0.116666, train error 0.80,  test loss 1.230461, test error 38.00
# Epoch    25, train loss 0.111069, train error 0.60,  test loss 1.246162, test error 38.00
# Epoch    26, train loss 0.104718, train error 0.47,  test loss 1.258896, test error 37.50
# Epoch    27, train loss 0.103318, train error 0.43,  test loss 1.277338, test error 38.30
# Epoch    28, train loss 0.094680, train error 0.35,  test loss 1.282599, test error 37.70
# Epoch    29, train loss 0.091928, train error 0.38,  test loss 1.290763, test error 38.30
# Epoch    30, train loss 0.086565, train error 0.20,  test loss 1.300900, test error 37.90
# Epoch    31, train loss 0.083964, train error 0.25,  test loss 1.298994, test error 37.80
# Epoch    32, train loss 0.081988, train error 0.22,  test loss 1.303692, test error 37.70
# Epoch    33, train loss 0.080168, train error 0.18,  test loss 1.318828, test error 38.30
# Epoch    34, train loss 0.078407, train error 0.18,  test loss 1.317056, test error 37.60
# Epoch    35, train loss 0.076291, train error 0.15,  test loss 1.325044, test error 37.60
# Epoch    36, train loss 0.074950, train error 0.15,  test loss 1.331357, test error 38.50
# Epoch    37, train loss 0.072894, train error 0.18,  test loss 1.334342, test error 37.70
# Epoch    38, train loss 0.071633, train error 0.15,  test loss 1.342957, test error 37.60
# Epoch    39, train loss 0.070154, train error 0.12,  test loss 1.350639, test error 37.60
# Epoch    40, train loss 0.068791, train error 0.10,  test loss 1.345989, test error 38.10
# Epoch    41, train loss 0.068004, train error 0.12,  test loss 1.355541, test error 37.80
# Epoch    42, train loss 0.067225, train error 0.10,  test loss 1.357068, test error 38.00
# Epoch    43, train loss 0.066515, train error 0.10,  test loss 1.358181, test error 38.10
# Epoch    44, train loss 0.065691, train error 0.10,  test loss 1.362832, test error 38.10
# Epoch    45, train loss 0.064926, train error 0.10,  test loss 1.363850, test error 38.00
# Epoch    46, train loss 0.064197, train error 0.07,  test loss 1.366633, test error 38.00
# Epoch    47, train loss 0.063599, train error 0.10,  test loss 1.367417, test error 38.00
# Epoch    48, train loss 0.063049, train error 0.10,  test loss 1.376312, test error 37.80
# Epoch    49, train loss 0.062250, train error 0.07,  test loss 1.374888, test error 37.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %%
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import StepLR

D_i = 40
D_o = 10

model = nn.Sequential(
    nn.Linear(D_i, 200),
    nn.ReLU(),
    nn.Linear(200, 200),
    nn.ReLU(),
    nn.Linear(200, D_o)
)

def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_normal_(layer_in.weight, nonlinearity='relu')
        nn.init.zeros_(layer_in.bias)

model.apply(weights_init)

loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test  = torch.tensor(data['x_test'].astype('float32'))
y_test  = torch.tensor(data['y_test'].astype('int64'))

data_loader = DataLoader(
    TensorDataset(x_train, y_train),
    batch_size=64,
    shuffle=True,
    worker_init_fn=np.random.seed(1)
)

n_epoch = 50
losses_train = np.zeros(n_epoch)
errors_train = np.zeros(n_epoch)
losses_test = np.zeros(n_epoch)
errors_test = np.zeros(n_epoch)

for epoch in range(n_epoch):
    for x_batch, y_batch in data_loader:
        optimizer.zero_grad()
        pred = model(x_batch)
        loss = loss_function(pred, y_batch)
        loss.backward()
        optimizer.step()

    pred_train = model(x_train)
    pred_test = model(x_test)

    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)

    errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test[epoch] = 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train[epoch] = loss_function(pred_train, y_train).item()
    losses_test[epoch] = loss_function(pred_test, y_test).item()

    print(f"Epoch {epoch:3d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:.2f}, test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:.2f}")

    # Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()
# Out:
# Epoch   0, train loss 1.594743, train error 60.65, test loss 1.739292, test error 68.50
# Epoch   1, train loss 1.398424, train error 49.97, test loss 1.597117, test error 63.30
# Epoch   2, train loss 1.245204, train error 42.90, test loss 1.496973, test error 59.30
# Epoch   3, train loss 1.124271, train error 36.70, test loss 1.431306, test error 54.20
# Epoch   4, train loss 1.019154, train error 31.88, test loss 1.345462, test error 51.30
# Epoch   5, train loss 0.927912, train error 29.30, test loss 1.305767, test error 50.10
# Epoch   6, train loss 0.851583, train error 27.03, test loss 1.255872, test error 48.80
# Epoch   7, train loss 0.764417, train error 22.57, test loss 1.227890, test error 47.10
# Epoch   8, train loss 0.706873, train error 20.32, test loss 1.202406, test error 47.70
# Epoch   9, train loss 0.637614, train error 17.35, test loss 1.167337, test error 43.60
# Epoch  10, train loss 0.593336, train error 16.95, test loss 1.164134, test error 45.40
# Epoch  11, train loss 0.533618, train error 13.78, test loss 1.140549, test error 44.10
# Epoch  12, train loss 0.494583, train error 12.57, test loss 1.139697, test error 43.50
# Epoch  13, train loss 0.447434, train error 10.70, test loss 1.118948, test error 44.80
# Epoch  14, train loss 0.397786, train error 8.90, test loss 1.121996, test error 42.50
# Epoch  15, train loss 0.356096, train error 6.55, test loss 1.130516, test error 42.80
# Epoch  16, train loss 0.321664, train error 6.03, test loss 1.120510, test error 40.80
# Epoch  17, train loss 0.283570, train error 4.32, test loss 1.139712, test error 42.00
# Epoch  18, train loss 0.253684, train error 3.07, test loss 1.110297, test error 42.10
# Epoch  19, train loss 0.224510, train error 2.45, test loss 1.132368, test error 39.70
# Epoch  20, train loss 0.203821, train error 2.03, test loss 1.141042, test error 42.10
# Epoch  21, train loss 0.180231, train error 1.47, test loss 1.143026, test error 40.20
# Epoch  22, train loss 0.156321, train error 0.93, test loss 1.150254, test error 39.80
# Epoch  23, train loss 0.146802, train error 1.32, test loss 1.185425, test error 38.30
# Epoch  24, train loss 0.126391, train error 0.45, test loss 1.184526, test error 40.30
# Epoch  25, train loss 0.108875, train error 0.32, test loss 1.187972, test error 40.00
# Epoch  26, train loss 0.097522, train error 0.18, test loss 1.187580, test error 38.90
# Epoch  27, train loss 0.085660, train error 0.03, test loss 1.198189, test error 39.30
# Epoch  28, train loss 0.080426, train error 0.07, test loss 1.232999, test error 38.40
# Epoch  29, train loss 0.068144, train error 0.00, test loss 1.221259, test error 39.50
# Epoch  30, train loss 0.059927, train error 0.00, test loss 1.236896, test error 38.80
# Epoch  31, train loss 0.052689, train error 0.00, test loss 1.261699, test error 39.00
# Epoch  32, train loss 0.049354, train error 0.00, test loss 1.275819, test error 39.30
# Epoch  33, train loss 0.042188, train error 0.00, test loss 1.269127, test error 38.60
# Epoch  34, train loss 0.038326, train error 0.00, test loss 1.292252, test error 38.20
# Epoch  35, train loss 0.037371, train error 0.00, test loss 1.315195, test error 39.10
# Epoch  36, train loss 0.032119, train error 0.00, test loss 1.316152, test error 38.90
# Epoch  37, train loss 0.029840, train error 0.00, test loss 1.325472, test error 38.00
# Epoch  38, train loss 0.027383, train error 0.00, test loss 1.334899, test error 39.00
# Epoch  39, train loss 0.025007, train error 0.00, test loss 1.344650, test error 38.50
# Epoch  40, train loss 0.022811, train error 0.00, test loss 1.366860, test error 38.80
# Epoch  41, train loss 0.020326, train error 0.00, test loss 1.371388, test error 39.20
# Epoch  42, train loss 0.018863, train error 0.00, test loss 1.395722, test error 38.90
# Epoch  43, train loss 0.017829, train error 0.00, test loss 1.391414, test error 38.90
# Epoch  44, train loss 0.016206, train error 0.00, test loss 1.427358, test error 39.10
# Epoch  45, train loss 0.014810, train error 0.00, test loss 1.425292, test error 38.60
# Epoch  46, train loss 0.014126, train error 0.00, test loss 1.434247, test error 39.00
# Epoch  47, train loss 0.013056, train error 0.00, test loss 1.454281, test error 38.20
# Epoch  48, train loss 0.012081, train error 0.00, test loss 1.460338, test error 38.00
# Epoch  49, train loss 0.011321, train error 0.00, test loss 1.473862, test error 38.60

# %% [markdown]
# **Tuning hyperparameters by repeatedly observing test-set performance is not a good practice, because it causes indirect overfitting to the test set. As a result, the final test error is no longer an unbiased estimate of true generalization performance. A better approach is to tune hyperparameters on a separate validation set and use the test set only once for final evaluation.**
