# %% [markdown]
# <a href="https://colab.research.google.com/github/Shuvo1523004/Deep-Learning/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-aoakqy3u
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-aoakqy3u
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=b6d6c8f70a3624e51d1997e96a60d4f893b4ca35cb27de769e3a25e61c28bfda
#   Stored in directory: /tmp/pip-ephem-wheel-cache-afnqy4p_/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.

D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    # First residual block
    h2 = self.linear2(h1).relu() + h1
    # Second residual block
    h3 = self.linear3(h2).relu() + h2
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.610067, train error 62.25,  val loss 1.700746, percent error 68.80
# Epoch     1, train loss 1.294713, train error 47.55,  val loss 1.428890, percent error 56.60
# Epoch     2, train loss 1.112102, train error 40.00,  val loss 1.289259, percent error 52.00
# Epoch     3, train loss 0.995422, train error 36.35,  val loss 1.233971, percent error 47.70
# Epoch     4, train loss 0.909543, train error 32.68,  val loss 1.205117, percent error 46.80
# Epoch     5, train loss 0.792186, train error 28.80,  val loss 1.129440, percent error 43.00
# Epoch     6, train loss 0.721708, train error 26.47,  val loss 1.151789, percent error 43.40
# Epoch     7, train loss 0.634436, train error 21.85,  val loss 1.112723, percent error 42.30
# Epoch     8, train loss 0.609398, train error 22.22,  val loss 1.176025, percent error 42.50
# Epoch     9, train loss 0.491720, train error 16.70,  val loss 1.165952, percent error 42.40
# Epoch    10, train loss 0.450541, train error 15.00,  val loss 1.173745, percent error 40.50
# Epoch    11, train loss 0.468837, train error 17.35,  val loss 1.314974, percent error 41.00
# Epoch    12, train loss 0.378175, train error 12.55,  val loss 1.185406, percent error 39.50
# Epoch    13, train loss 0.379657, train error 13.70,  val loss 1.303279, percent error 41.20
# Epoch    14, train loss 0.275358, train error 8.78,  val loss 1.254927, percent error 37.10
# Epoch    15, train loss 0.249080, train error 8.18,  val loss 1.261420, percent error 36.50
# Epoch    16, train loss 0.233566, train error 8.00,  val loss 1.382674, percent error 37.40
# Epoch    17, train loss 0.160481, train error 4.35,  val loss 1.311473, percent error 35.50
# Epoch    18, train loss 0.165480, train error 5.18,  val loss 1.391532, percent error 35.10
# Epoch    19, train loss 0.137406, train error 4.10,  val loss 1.490324, percent error 37.10
# Epoch    20, train loss 0.058627, train error 0.22,  val loss 1.347591, percent error 35.00
# Epoch    21, train loss 0.040330, train error 0.05,  val loss 1.380275, percent error 34.90
# Epoch    22, train loss 0.032681, train error 0.03,  val loss 1.413257, percent error 34.50
# Epoch    23, train loss 0.027306, train error 0.00,  val loss 1.425443, percent error 34.40
# Epoch    24, train loss 0.025077, train error 0.00,  val loss 1.455265, percent error 34.60
# Epoch    25, train loss 0.021764, train error 0.00,  val loss 1.479475, percent error 33.70
# Epoch    26, train loss 0.019451, train error 0.00,  val loss 1.494000, percent error 34.00
# Epoch    27, train loss 0.017909, train error 0.00,  val loss 1.517680, percent error 34.00
# Epoch    28, train loss 0.016364, train error 0.00,  val loss 1.536807, percent error 34.10
# Epoch    29, train loss 0.015099, train error 0.00,  val loss 1.556943, percent error 34.30
# Epoch    30, train loss 0.014149, train error 0.00,  val loss 1.573182, percent error 34.00
# Epoch    31, train loss 0.013101, train error 0.00,  val loss 1.592697, percent error 34.40
# Epoch    32, train loss 0.012355, train error 0.00,  val loss 1.609162, percent error 33.90
# Epoch    33, train loss 0.011458, train error 0.00,  val loss 1.617785, percent error 33.80
# Epoch    34, train loss 0.010917, train error 0.00,  val loss 1.631778, percent error 33.70
# Epoch    35, train loss 0.010266, train error 0.00,  val loss 1.644323, percent error 34.40
# Epoch    36, train loss 0.009779, train error 0.00,  val loss 1.660158, percent error 34.00
# Epoch    37, train loss 0.009289, train error 0.00,  val loss 1.669407, percent error 33.80
# Epoch    38, train loss 0.008785, train error 0.00,  val loss 1.679947, percent error 34.00
# Epoch    39, train loss 0.008442, train error 0.00,  val loss 1.694828, percent error 34.10
# Epoch    40, train loss 0.008155, train error 0.00,  val loss 1.700300, percent error 34.00
# Epoch    41, train loss 0.007977, train error 0.00,  val loss 1.703404, percent error 33.90
# Epoch    42, train loss 0.007796, train error 0.00,  val loss 1.709273, percent error 34.10
# Epoch    43, train loss 0.007640, train error 0.00,  val loss 1.714426, percent error 34.30
# Epoch    44, train loss 0.007481, train error 0.00,  val loss 1.718061, percent error 34.00
# Epoch    45, train loss 0.007326, train error 0.00,  val loss 1.723067, percent error 34.00
# Epoch    46, train loss 0.007193, train error 0.00,  val loss 1.731401, percent error 34.50
# Epoch    47, train loss 0.007053, train error 0.00,  val loss 1.735694, percent error 34.20
# Epoch    48, train loss 0.006907, train error 0.00,  val loss 1.739905, percent error 34.20
# Epoch    49, train loss 0.006780, train error 0.00,  val loss 1.742956, percent error 33.90
# Epoch    50, train loss 0.006657, train error 0.00,  val loss 1.745697, percent error 33.90
# Epoch    51, train loss 0.006544, train error 0.00,  val loss 1.751991, percent error 34.00
# Epoch    52, train loss 0.006422, train error 0.00,  val loss 1.755416, percent error 33.80
# Epoch    53, train loss 0.006317, train error 0.00,  val loss 1.762067, percent error 34.00
# Epoch    54, train loss 0.006196, train error 0.00,  val loss 1.766899, percent error 34.00
# Epoch    55, train loss 0.006088, train error 0.00,  val loss 1.768005, percent error 33.90
# Epoch    56, train loss 0.005977, train error 0.00,  val loss 1.775340, percent error 34.10
# Epoch    57, train loss 0.005885, train error 0.00,  val loss 1.777078, percent error 33.90
# Epoch    58, train loss 0.005788, train error 0.00,  val loss 1.783738, percent error 34.00
# Epoch    59, train loss 0.005741, train error 0.00,  val loss 1.785721, percent error 34.00
# Epoch    60, train loss 0.005639, train error 0.00,  val loss 1.789182, percent error 33.90
# Epoch    61, train loss 0.005593, train error 0.00,  val loss 1.792119, percent error 34.00
# Epoch    62, train loss 0.005548, train error 0.00,  val loss 1.793567, percent error 34.00
# Epoch    63, train loss 0.005503, train error 0.00,  val loss 1.795900, percent error 34.00
# Epoch    64, train loss 0.005463, train error 0.00,  val loss 1.796896, percent error 34.10
# Epoch    65, train loss 0.005418, train error 0.00,  val loss 1.799444, percent error 33.90
# Epoch    66, train loss 0.005377, train error 0.00,  val loss 1.801507, percent error 34.00
# Epoch    67, train loss 0.005335, train error 0.00,  val loss 1.803011, percent error 34.00
# Epoch    68, train loss 0.005294, train error 0.00,  val loss 1.805536, percent error 34.10
# Epoch    69, train loss 0.005254, train error 0.00,  val loss 1.807468, percent error 34.10
# Epoch    70, train loss 0.005214, train error 0.00,  val loss 1.809101, percent error 34.10
# Epoch    71, train loss 0.005175, train error 0.00,  val loss 1.810874, percent error 34.10
# Epoch    72, train loss 0.005136, train error 0.00,  val loss 1.812912, percent error 34.10
# Epoch    73, train loss 0.005098, train error 0.00,  val loss 1.814617, percent error 34.10
# Epoch    74, train loss 0.005061, train error 0.00,  val loss 1.816711, percent error 34.00
# Epoch    75, train loss 0.005024, train error 0.00,  val loss 1.818650, percent error 34.00
# Epoch    76, train loss 0.004989, train error 0.00,  val loss 1.821543, percent error 33.90
# Epoch    77, train loss 0.004952, train error 0.00,  val loss 1.822518, percent error 34.00
# Epoch    78, train loss 0.004917, train error 0.00,  val loss 1.823448, percent error 33.90
# Epoch    79, train loss 0.004881, train error 0.00,  val loss 1.825840, percent error 34.00
# Epoch    80, train loss 0.004863, train error 0.00,  val loss 1.827044, percent error 33.90
# Epoch    81, train loss 0.004845, train error 0.00,  val loss 1.827425, percent error 34.10
# Epoch    82, train loss 0.004828, train error 0.00,  val loss 1.828663, percent error 34.00
# Epoch    83, train loss 0.004811, train error 0.00,  val loss 1.829285, percent error 34.10
# Epoch    84, train loss 0.004794, train error 0.00,  val loss 1.830023, percent error 34.00
# Epoch    85, train loss 0.004777, train error 0.00,  val loss 1.831189, percent error 34.00
# Epoch    86, train loss 0.004760, train error 0.00,  val loss 1.832043, percent error 34.00
# Epoch    87, train loss 0.004744, train error 0.00,  val loss 1.832998, percent error 34.00
# Epoch    88, train loss 0.004727, train error 0.00,  val loss 1.834221, percent error 34.00
# Epoch    89, train loss 0.004711, train error 0.00,  val loss 1.834323, percent error 34.00
# Epoch    90, train loss 0.004694, train error 0.00,  val loss 1.835790, percent error 34.00
# Epoch    91, train loss 0.004679, train error 0.00,  val loss 1.836375, percent error 34.00
# Epoch    92, train loss 0.004663, train error 0.00,  val loss 1.837677, percent error 34.00
# Epoch    93, train loss 0.004647, train error 0.00,  val loss 1.838503, percent error 34.00
# Epoch    94, train loss 0.004631, train error 0.00,  val loss 1.839356, percent error 34.00
# Epoch    95, train loss 0.004615, train error 0.00,  val loss 1.840023, percent error 34.00
# Epoch    96, train loss 0.004600, train error 0.00,  val loss 1.841093, percent error 34.00
# Epoch    97, train loss 0.004584, train error 0.00,  val loss 1.841879, percent error 34.00
# Epoch    98, train loss 0.004569, train error 0.00,  val loss 1.842448, percent error 34.00
# Epoch    99, train loss 0.004553, train error 0.00,  val loss 1.843306, percent error 34.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
